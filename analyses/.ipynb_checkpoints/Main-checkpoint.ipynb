# %%
# This is Main function.
# Extracting streaming data from Twitter, pre-processing, and loading into MySQL
import credentials # Import api/access_token keys from credentials.py
import settings # Import related setting constants from settings.py 

import re
import tweepy
import mysql.connector
import pandas as pd
from textblob import TextBlob
# Streaming With Tweepy 
# http://docs.tweepy.org/en/v3.4.0/streaming_how_to.html#streaming-with-tweepy

# %%
# Override tweepy.StreamListener to add logic to on_status
class MyStreamListener(tweepy.StreamListener):
    '''
    Tweets are known as “status updates”. So the Status class in tweepy has properties describing the tweet.
    https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/tweet-object.html
    '''
    
    def on_status(self, status):
        '''
        Extract info from tweets
        '''
        
        if status.retweeted:
            # Avoid retweeted info, and only original tweets will be received
            return True
        # Extract attributes from each tweet
        id_str = status.id_str
        created_at = status.created_at
        text = deEmojify(status.text)    # Pre-processing the text  
        sentiment = TextBlob(text).sentiment
        polarity = sentiment.polarity
        subjectivity = sentiment.subjectivity
        
        user_created_at = status.user.created_at
        user_location = deEmojify(status.user.location)
        user_description = deEmojify(status.user.description)
        user_followers_count =status.user.followers_count
        longitude = None
        latitude = None
        if status.coordinates:
            longitude = status.coordinates['coordinates'][0]
            latitude = status.coordinates['coordinates'][1]
            
        retweet_count = status.retweet_count
        favorite_count = status.favorite_count
        
        print(status.text)
        print("Long: {}, Lati: {}".format(longitude, latitude))
        
        # Store all data in MySQL
        if mydb.is_connected():
            mycursor = mydb.cursor()
            sql = "INSERT INTO {} (id_str, created_at, text, polarity, subjectivity, user_created_at, user_location, user_description, user_followers_count, longitude, latitude, retweet_count, favorite_count) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)".format(settings.TABLE_NAME)
            val = (id_str, created_at, text, polarity, subjectivity, user_created_at, user_location, \
                user_description, user_followers_count, longitude, latitude, retweet_count, favorite_count)
            mycursor.execute(sql, val)
            mydb.commit()
            mycursor.close()
    
    
    def on_error(self, status_code):
        '''
        Since Twitter API has rate limits, stop srcraping data as it exceed to the thresold.
        '''
        if status_code == 420:
            # return False to disconnect the stream
            return False

# %%
def clean_tweet(self, tweet): 
    ''' 
    Use sumple regex statemnents to clean tweet text by removing links and special characters
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) \
                                |(\w+:\/\/\S+)", " ", tweet).split()) 
def deEmojify(text):
    '''
    Strip all non-ASCII characters to remove emoji characters
    '''
    if text:
        return text.encode('ascii', 'ignore').decode('ascii')
    else:
        return None

# %%
#change table name(s) in settings.py
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    passwd="Datasci92!",
    database="Twitter",
    charset = 'utf8'
)#prbly have to create table via mysql
if mydb.is_connected():
    '''
    Check if this table exits. If not, then create a new one.
    '''
    mycursor = mydb.cursor()
    mycursor.execute("""
        SELECT COUNT(*)
        FROM information_schema.tables
        WHERE table_name = '{0}'
        """.format(settings.TABLE_NAME))
    if mycursor.fetchone()[0] != 1:
        mycursor.execute("CREATE TABLE {} ({})".format(settings.TABLE_NAME, settings.TABLE_ATTRIBUTES))
        mydb.commit()
    mycursor.close()

# %%
auth  = tweepy.OAuthHandler(credentials.API_KEY, credentials.API_SECRET_KEY)
auth.set_access_token(credentials.ACCESS_TOKEN, credentials.ACCESS_TOKEN_SECRET)#watch misspelled "ACCESS_TOEKN"
api = tweepy.API(auth)

# %%
myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
myStream.filter(languages=["en"], track = settings.TRACK_WORDS)
# Close the MySQL connection as it finished
# However, this won't be reached as the stream listener won't stop automatically
# Press STOP button to finish the process.
mydb.close()
# Out:
# RT @ben_rosen: *somber music plays as millie bobbie brown sneaks into an english farmhouse*
#
# *she moves a floorboard and finds a pile of du…
# Long: None, Lati: None
# @trivia_vantae @ghostlyjihoon @Ioveforjjk Um, okay? Another thing, your entire life doesn't have to revolve around… https://t.co/q6HIBE30eP
# Long: None, Lati: None
# so it's pretty sure that gfriend is coming back in january hhhhH YES
# Long: None, Lati: None
# GO GET THE BOYS A DAESANG! GO VOTE!!
# Long: None, Lati: None
# Let a man live his life. If he's happy, then be happy for him. The music will come.
#
# The bigger problem is the drug… https://t.co/5BvEnbrgQU
# Long: None, Lati: None
# like yes LA fans get a lot. but also LA is like where tf the music scene in america is so idk why people are still… https://t.co/wcFwN5Vozg
# Long: None, Lati: None
# RT @ladygaganownet: Lady Gaga’s art cover for Born This Way has been named by @i_D as one of the ‘10 Moments That Defined Pop Music’ this d…
# Long: None, Lati: None
# RT @glittering_mc: “Having @tiktok_us as a platform where new generations can discover music from different times is so amazing. I particul…
# Long: None, Lati: None
# RT @tiffanicvd: Me trying to listen to JUICE WRLD 🧃 now .. 😭😭😭
#
# Taken too soon.
#
# #juicewrld #music
#
# https://t.co/pOXUAlwTAC
# Long: None, Lati: None
# iTunes Mexico
#
# #17. Obsession (NEW) *peak 1*
#
# #BuyObsessionOniTunes
# https://t.co/FoQswLsyD4
# Long: None, Lati: None
# Mouth music calmed my reservation
# Lulled me into dreams of you.
# Still I took pause
# At heart I knew.
# When morning ca… https://t.co/LngQYzbjmv
# Long: None, Lati: None
# On 95 🔨 🔫 on my side  https://t.co/Lddq01dBMI
# Long: None, Lati: None
# RT @BTF_SOSA: I can listen to old music all day
# Long: None, Lati: None
# STREAM BARBIES
# Long: None, Lati: None
# RT @ellxsig: You know you’re getting old when youd rather listen to podcasts in the car than play music.
# Long: None, Lati: None
# RT @julieUBERsidad: Of course ❤️ https://t.co/ravYpRQsMG
# Long: None, Lati: None
# Listen to 600Breezy - Murder Rate Music by ATLPLUG #np on #SoundCloud 🦍🦍🦍🤕 https://t.co/ZtCfEHSMti
# Long: None, Lati: None
# RT @FenWhitney: Hey.
# The world is tough.
# So I made a 30 second video of playing fetch with a Snom in the snow, set to calming Animal Cros…
# Long: None, Lati: None
# RT @sinful_lola: On day Kanye will release an empty cd album and tell fans to imagine the music.
#
# They’ll be like “this is genius, I hear i…
# Long: None, Lati: None
# RT @rikognition: Thanks for 6k on IG!
# @LeagueOfLegends True Damage Akali #cosplay #photomotion ft. @StellaChuuuuu
# Music by @TheNightShift…
# Long: None, Lati: None
# This Thursday! [12.12] @lostsocietydc • A special edition of getlostdc_
# feat. everythingnicedc +
# music by… https://t.co/D4EtRgd7fA
# Long: None, Lati: None
# RT @exoscharts: iTunes Brazil
# RT @k__taaylor: Until we address that drugs is major cause of death in the music industry, we are going to have way more fallen soldiers. #…
# Long: None, Lati: None
# RT @rikognition: Thanks for 6k on IG!
# @LeagueOfLegends True Damage Akali #cosplay #photomotion ft. @StellaChuuuuu
# Music by @TheNightShift…
# Long: None, Lati: None
# Somebody put me on to some new music.
# Long: None, Lati: None
# RT @exoscharts: iTunes US
#
# #55. Obsession (+3) *peak 2*
#
# #BuyObsessionOniTunes
# https://t.co/FoQswLsyD4
# Long: None, Lati: None
# Coming Up on More Music Mornings in the next 15 minutes Matchbox 20, Cyndi Lauper and Meghan Trainor!… https://t.co/CqVNyTPkfc
# Long: None, Lati: None
# RT @djjyn: EKKO Music Rights, apparently behind upcoming LOONA track 365 (or related to), have writers and producers who worked on songs su…
# Long: None, Lati: None
# RT @nwalks: Many of you fools have only discovered Immigrant Song through the Thor movie unlike ME, a Cool girl who Knows Music, who learne…
# Long: None, Lati: None
# RT @BigHitEnt: [기사] #BTS Says New Music Coming Soon
# https://t.co/Dkrvc7G32Q
# Long: None, Lati: None
# RT @JAILEEGANG: I overplayed all the music on my phone. I need new music.
# Long: None, Lati: None
# RT @DothTheDoth: The only music I like is the out of tune piano you hear playing from the basement before you are murdered.
# Long: None, Lati: None
# RT @_kequann: Me listening to music tryna find a caption for my picture https://t.co/Z8aYJzrI9k
# Long: None, Lati: None
# RT @shadocoon: fbyleth’s brain: elevator music
# mbyleth’s brain: dial tone https://t.co/sIhiFbVWR7
# Long: None, Lati: None
# RT @FenWhitney: Hey.
# The world is tough.
# So I made a 30 second video of playing fetch with a Snom in the snow, set to calming Animal Cros…
# Long: None, Lati: None
# RT @btsdailystats: ⚠️ Seoul Music Awards ⚠️
#
# ▪ Main Award
# #1        - 14.99% (31351 votes)
# #2 BTS - 13.05% (27282 votes)
#
# ▪ K-wave Award…
# Long: None, Lati: None
# @MYSTIC_YERI Thanks I love EXO and this music too ^^
# Long: None, Lati: None
# RT @USEmbassySeoul: Power of music! Before @BTS_twt went on stage to open #JingleBall2019, they spent time interacting with #ARMYs, includi…
# Long: None, Lati: None
# @Rainbow6Game That was not the music I was expecting- I thought I launched the game by accident lol
# Long: None, Lati: None
# RT @GlynBrwn: If you not Hip to Lancey Foux
#
# You are not musically inclined . https://t.co/fBXKltp7hG
# Long: None, Lati: None
# RT @Emmuel_Reyes: DONT FIND A REPLACEMENT FOR JUICE WRLD SET NEXT WEEK JUST HAVE A DJ PLAY HIS MUSIC FOR AN HOUR💔 LET US FANS MOURN TOGETHE…
# Long: None, Lati: None
# @silverdowney @robeliasjr because like,,,she made a music vid for it ok bye pray for me
# Long: None, Lati: None
# RT @AndresJavierNYC: Let's Skip Work, Stay In and Listen to #Music
# #Reckless, my debut EP, is Out
# 4 songs, 16 minutes - "beautiful things…
# Long: None, Lati: None
# Please Listen My Music!
#
# kakicchysmusic on Spotify via Spotify https://t.co/oEh4OqfQo5
# Long: None, Lati: None
# RT @urrrrrpapiiiii: if you use Music as sleeping pill, retweet this.
# Long: None, Lati: None
# @kevinabstract BEST BE SUGAR MUSIC VIDEO
# Long: None, Lati: None
# RT @sinfulpluto: full moon on the 12th. start cleaning. https://t.co/AePFAemSZx
# Long: None, Lati: None
# RT @IZONE_stats: [🇰🇷] @official_izone is currently #1 in the main category of High1 Seoul Music Award!
#
# keep supporting and voting for the…
# Long: None, Lati: None
# RT @PiyushSingh083: You say Nehru
# We hear Partition.
#
# You Say Indira
# We hear Emergency.
#
# You say Rajiv Gandhi
# We hear operation Blue Star.…
# Long: None, Lati: None
# RT @halielynn34: You aint even gotta be fan but you cant lie and say that their music didn't help a lot of people. These 4 right here had m…
# Long: None, Lati: None
# when u ask u favs for new music and they say “soon”😔 https://t.co/cGBtTdZjr0
# Long: None, Lati: None
# RT @MarvelRealm: If fighting a Secret War will prevent an open one ... will you join us? Battleworld will rise in 2020 in Marvel Realm of C…
# Long: None, Lati: None
# RT @exoscharts: iTunes US
#
# #55. Obsession (+3) *peak 2*
#
# #BuyObsessionOniTunes
# https://t.co/FoQswLsyD4
# Long: None, Lati: None
# RT @exoscharts: iTunes Mexico
#
# #17. Obsession (NEW) *peak 1*
#
# #BuyObsessionOniTunes
# https://t.co/FoQswLsyD4
# Long: None, Lati: None
# RT @OMGTheMess: We have failed our kids https://t.co/gOLV7xP0SP
# Long: None, Lati: None
# I must really like you
# Cause not a lot of guys are worth my time! https://t.co/ufTutQWdcy
# Long: None, Lati: None
# RT @TWICETrends: 🏆Seoul Music Awards 📊
# 📅 (12.09-01.22)
#
# Voting already started, @JYPETWICE is nominated in 3 categories: Main, K-Wave, and…
# Long: None, Lati: None
# RT @djjyn: LOONA's '365' will be released on each music site at 6 pm KST on the 13th (December) 🙏
#
# We buying it, we buying a lot of it
# Long: None, Lati: None
# RT @btsdailystats: ⚠️ Seoul Music Awards ⚠️
#
# ▪ Main Award
# #1        - 14.99% (31351 votes)
# #2 BTS - 13.05% (27282 votes)
#
# ▪ K-wave Award…
# Long: None, Lati: None
# RT @JeremyWest: A week after breaking house records and completely turning the show into a total and utter success story, the rumors have b…
# Long: None, Lati: None
# RT @loonalog: NEW MUSIC FROM LOONA AND A WORLD TOUR IN 2020 https://t.co/2qqPJpiIQS
# Long: None, Lati: None
# RT @matchu_chutrain: Three months ago I was crying every single day when I drove home from work because I was so unhappy with my life.
#
# I’…
# Long: None, Lati: None
# RT @exoscharts: iTunes Mexico
#
# #17. Obsession (NEW) *peak 1*
#
# #BuyObsessionOniTunes
# https://t.co/FoQswLsyD4
# Long: None, Lati: None
# @owenbroadcast it's meant to be a joke, all of his music videos are like this
# Long: None, Lati: None
# RT @exoscharts: iTunes Philippines
#
# #2. Obsession (+26) *peak 1*
#
# #BuyObsessionOniTunes
# https://t.co/FoQswLsyD4
# Long: None, Lati: None
# @jussbrennan @Akademiks how do you check your apple music shit
# Long: None, Lati: None
# RT @_kequann: Me listening to music tryna find a caption for my picture https://t.co/Z8aYJzrI9k
# Long: None, Lati: None
# When the 80s music comes on and the pomegranate hits
# Long: None, Lati: None
# @ZaOneAboveAll Highkey one of the few things I am having fun with, even changed up the music in this clip.
#
# Buonano… https://t.co/hhaILakRjj
# Long: None, Lati: None
# RT @exoscharts: iTunes Philippines
# OTD in 1965, CBS gambled big on an animated special: “A Charlie Brown Christmas." The show incorporated unexpected… https://t.co/5o9NdXPgEl
# Long: None, Lati: None
# RT @itsHunterJames: ATTN. ARTISTS! I'm doing a Spotify playlist placement giveaway.. 100% free to enter, and if your music is dope, you mig…
# Long: None, Lati: None
# RT @iriszha00759176: let's fighting!
# #LetsBeForeverIZONE https://t.co/Qp8wFXlH1i
# Long: None, Lati: None
# RT @exoscharts: iTunes US
#
# #55. Obsession (+3) *peak 2*
#
# #BuyObsessionOniTunes
# https://t.co/FoQswLsyD4
# Long: None, Lati: None
# They played the Batman movie music and I cheered a little #CrisisOnInfiniteEarths
# Long: None, Lati: None
# RT @BTSVotingFam: [Seoul Music Awards]
#
# We know the app is frustrating but please don't give up. Let's do our best for @BTS_twt!
#
# 🏆 Main A…
# Long: None, Lati: None
# RT @LaurenCimorelli: Thank you guys so much 🧡🧡🧡 Had no idea what to expect when I started releasing music at the beginning of this year and…
# Long: None, Lati: None
# RT @dlwodud93: 191207 &lt; Love, Poem &gt; Concert in Singapore 🇸🇬 Day2
# 아이유(@lily199iu)직찍 4pic by물론재영
#
# 🐥: I will come back to keep our promise! S…
# Long: None, Lati: None
# RT @exoscharts: iTunes Mexico
#
# #17. Obsession (NEW) *peak 1*
#
# #BuyObsessionOniTunes
# https://t.co/FoQswLsyD4
# Long: None, Lati: None
# Golden Disc Awards NetEase Cloud Music's most popular K-pop star award #BTS votes have exceeded 10 million. 🎊
# Admir… https://t.co/2lmyBVMPNv
# Long: None, Lati: None
# RT @_kequann: Me listening to music tryna find a caption for my picture https://t.co/Z8aYJzrI9k
# Long: None, Lati: None
# RT @TyleKurner: Sondheim! Everywhere Sondheim! for @vulture, i got to speak with @rianjohnson, Noah Baumbach, and JOKER's music supervisor,…
# Long: None, Lati: None
# RT @SJWWVT: SEOUL MUSIC AWARDS
#
# Voting Period
#
# 09.12.2019 12NN KST - 22.01.2020 12MN KST
#
# Nominated in 2 categories
# ☑ MAIN
# ☑ KWAVE
#
# Downloa…
# Long: None, Lati: None
# RT @jazzemu_: I am a music historian, and with @AdrianRMG I have researched the best-selling single of every decade all the way back to 14,…
# Long: None, Lati: None
# RT @BTSVotingFam: [Seoul Music Awards]
#
# We know the app is frustrating but please don't give up. Let's do our best for @BTS_twt!
#
# 🏆 Main A…
# Long: None, Lati: None
# RT @_kequann: Me listening to music tryna find a caption for my picture https://t.co/Z8aYJzrI9k
# Long: None, Lati: None
# RT @shadocoon: fbyleth’s brain: elevator music
# mbyleth’s brain: dial tone https://t.co/sIhiFbVWR7
# Long: None, Lati: None
# RT @killshot40: "You'll like BTS music if you listen without prejudice"
#                      - Min Yoongi https://t.co/1qN050nC0f
# Long: None, Lati: None
# RT @AndrewQuackson: *looking at notes* its drugs https://t.co/cj61qRXCU8
# Long: None, Lati: None
# RT @exoscharts: iTunes Philippines
#
# #2. Obsession (+26) *peak 1*
#
# #BuyObsessionOniTunes
# https://t.co/FoQswLsyD4
# Long: None, Lati: None
# RT @hobipersona: an interviewer finally asked bts about the storyline they create through their music. FINALLY. this is why liam is the bes…
# Long: None, Lati: None
# the dance effects is amazing!
# #2. Obsession (+26) *peak 1*
#
# #BuyObsessionOniTunes
# https://t.co/FoQswLsyD4
# Long: None, Lati: None
# RT @indigoblvd: Pardon my language but fuck this shit move Beetlejuice to the Marquis or the Lyceum https://t.co/WeSMqElDFX
# Long: None, Lati: None
# RT @exoscharts: iTunes US Songs
#
# #514. Obsession (+240)
#
# #BuyObsessionOniTunes
# https://t.co/FoQswLsyD4
# Long: None, Lati: None
# RT @richbrian: me when i retire from music &amp; become a kindergarten teacher https://t.co/5QsygpnX0A
# Long: None, Lati: None
# RT @JAILEEGANG: I overplayed all the music on my phone. I need new music.
# Long: None, Lati: None
# Music for the #chillout and #ambient styles.  https://t.co/crt34oQ9QV
# New album coming 12.21.17.  Join the Chill Vi… https://t.co/ZzkBiliAPB
# Long: None, Lati: None
# RT @2011apink2: 29th Seoul Music Awards Announces Nominees + Voting Begins [ https://t.co/jpBfB11SDQ ]  Don't forget to VOTE for Apink #에이핑…
# Long: None, Lati: None
# RT @shadocoon: fbyleth’s brain: elevator music
# mbyleth’s brain: dial tone https://t.co/sIhiFbVWR7
# Long: None, Lati: None
# RT @IZONEGLOBALTW: 💡Focus on the main category!
#
# Main award is based on 40% judge + 30% sales + 30% voting result.
#
# IZ*ONE is rank 10 for t…
# Long: None, Lati: None
# This interview is so precious 💜Joonie said he's proud of us 😭
# Hobi looks so happy to make his statements, so fluent… https://t.co/Pi8XCYSkfV
# Long: None, Lati: None
# RT @BTSVotingFam: [Seoul Music Awards]
#
# We know the app is frustrating but please don't give up. Let's do our best for @BTS_twt!
#
# 🏆 Main A…
# Long: None, Lati: None
# RT @Camm3310: House music is the answer to everything
# Long: None, Lati: None
# RT @FenWhitney: Hey.
# The world is tough.
# So I made a 30 second video of playing fetch with a Snom in the snow, set to calming Animal Cros…
# Long: None, Lati: None
# RT @SJWWVT: SEOUL MUSIC AWARDS
#
# Voting Period
#
# 09.12.2019 12NN KST - 22.01.2020 12MN KST
#
# Nominated in 2 categories
# ☑ MAIN
# ☑ KWAVE
#
# Downloa…
# Long: None, Lati: None
# RT @crystalbell: Some thoughts on #Levanter and the realization that the map is ultimately *yours* to make. For @Stray_Kids, who have been…
# Long: None, Lati: None
# RT @Randbreloaded: #NYC #holidays are here if you plan on #travel to #NYC, enjoy #music, #food and drink events you should check out https:…
# Long: None, Lati: None
# RT @DOUBOISTACKS900: I’m gonna leave this gem here. Thank you juice wrld for everything, you were a blessing to the music community. https:…
# Long: None, Lati: None
# RT @hsnewsupdate: “Harry is a unicorn. It couldn’t be more important for music to have someone with the platform he has willing to take ris…
# Long: None, Lati: None
# RT @AWYTEAM: Sorry but exactly, we have max 5 votes/ category/ day so please focus on Bonsang
#
# #GOT7 @GOT7Official https://t.co/DdHesKx66N
# Long: None, Lati: None
# RT @JAILEEGANG: I overplayed all the music on my phone. I need new music.
# Long: None, Lati: None
# RT @exoscharts: iTunes Mexico
#
# #17. Obsession (NEW) *peak 1*
#
# #BuyObsessionOniTunes
# https://t.co/FoQswLsyD4
# Long: None, Lati: None
# RT @WWEGraves: The didn’t play MY entrance music for my divorce hearing.
#
# I feel short changed.
#
# IT’S GAMEDAYYYYYYYY
#
# #ThunderUp https://t.co/gHkvXWLtvo
# Long: None, Lati: None
# My son is not allowed to listen to his music. I’ll be damned 😭
# Long: None, Lati: None
# What’s wrong with him
# Long: None, Lati: None
# RT @bri_briannna: Posting music on your story even tho no one gives a fuck &gt;&gt; lmao
# Long: None, Lati: None
# RT @Ride4Black: Ladies 🤞🏾
# https://t.co/UrC7qWYHCM
# Long: None, Lati: None
# RT @playbill: Beetlejuice will close as The Music Man revival, starring Hugh Jackman and Sutton Foster, secures the Winter Garden Theatre:…
# Long: None, Lati: None
# Man this shit sad g
# Long: None, Lati: None
# RT @Nana_EW0330: K-wave is 100% global fans voting
#
# 29th Seoul Music Awards Announces Nominees   Voting Begins https://t.co/vduVMxKJLm via…
# Long: None, Lati: None
# RT @cliqik: -Davido is richer than Ghana
# -Wizkid is bigger than Ghana music industry
# -Tiwa got signed to an American rec label
# -Even Mayork…
# Long: None, Lati: None
# RT @halielynn34: You aint even gotta be fan but you cant lie and say that their music didn't help a lot of people. These 4 right here had m…
# Long: None, Lati: None
# Oh.
#
# Well this should be...interesting.😯
# Long: None, Lati: None
# RT @_kequann: Me listening to music tryna find a caption for my picture https://t.co/Z8aYJzrI9k
# Long: None, Lati: None
# @kinopachi @PhazonLover In terms of difficulty, yeah it’s easy. But that doesn’t change everything else, like story… https://t.co/t1yw2Cu6Av
# Long: None, Lati: None
# RT @FenWhitney: Hey.
# The world is tough.
# So I made a 30 second video of playing fetch with a Snom in the snow, set to calming Animal Cros…
# Long: None, Lati: None
# LIKE GUYS LISTEN TO THIS https://t.co/nJ6BQfl3rH
# Long: None, Lati: None
# RT @ben_rosen: *somber music plays as millie bobbie brown sneaks into an english farmhouse*
#
# *she moves a floorboard and finds a pile of du…
# Long: None, Lati: None
# RT @btsvotingteam: &lt; SEOUL MUSIC AWARDS &gt;
#
# 🗳Update: 10AM KST
# #2 Main           — -4,195
# #2 Kwave        — -2,748 (+1,159) ↓
# #2 Popularity…
# Long: None, Lati: None
# RT @TonyCast83: @Ghostbusters Make a trailer with the original music!!! 😛 https://t.co/Vv8L5fwDPt
# Long: None, Lati: None
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# ~/.pyenv/versions/3.7.1/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     580                 if len(mvb) <= chunk_left:
# --> 581                     n = self._safe_readinto(mvb)
#     582                     self.chunk_left = chunk_left - n
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/http/client.py in _safe_readinto(self, b)
#     627             if not n:
# --> 628                 raise IncompleteRead(bytes(mvb[0:total_bytes]), len(b))
#     629             mvb = mvb[n:]
#
# IncompleteRead: IncompleteRead(0 bytes read, 512 more expected)
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# ~/.ve/jupyter/lib/python3.7/site-packages/urllib3/response.py in _error_catcher(self)
#     424             try:
# --> 425                 yield
#     426
#
# ~/.ve/jupyter/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/http/client.py in read(self, amt)
#     446             b = bytearray(amt)
# --> 447             n = self.readinto(b)
#     448             return memoryview(b)[:n].tobytes()
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/http/client.py in readinto(self, b)
#     480         if self.chunked:
# --> 481             return self._readinto_chunked(b)
#     482
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     591         except IncompleteRead:
# --> 592             raise IncompleteRead(bytes(b[0:total_bytes]))
#     593
#
# IncompleteRead: IncompleteRead(0 bytes read)
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# <ipython-input-6-ff56b86508dd> in <module>
#       1 myStreamListener = MyStreamListener()
#       2 myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
# ----> 3 myStream.filter(languages=["en"], track = settings.TRACK_WORDS)
#       4 # Close the MySQL connection as it finished
#       5 # However, this won't be reached as the stream listener won't stop automatically
#
# ~/.ve/jupyter/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~/.ve/jupyter/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~/.ve/jupyter/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     318             # call a handler first so that the exception can be logged.
#     319             self.listener.on_exception(exc_info[1])
# --> 320             six.reraise(*exc_info)
#     321
#     322     def _data(self, data):
#
# ~/.pyenv/versions/jupyter3/lib/python3.7/site-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# ~/.ve/jupyter/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~/.ve/jupyter/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~/.ve/jupyter/lib/python3.7/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~/.ve/jupyter/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     527                         # raised during streaming, so all calls with incorrect
#     528                         # Content-Length are caught.
# --> 529                         raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#     530
#     531         if data:
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# ~/.ve/jupyter/lib/python3.7/site-packages/urllib3/response.py in _error_catcher(self)
#     441             except (HTTPException, SocketError) as e:
#     442                 # This includes IncompleteRead.
# --> 443                 raise ProtocolError("Connection broken: %r" % e, e)
#     444
#     445             # If no exception is thrown, we should avoid cleaning up
#
# ProtocolError: ('Connection broken: IncompleteRead(0 bytes read)', IncompleteRead(0 bytes read))

# %%
# preselec(quidproquo) or current events dash app?
